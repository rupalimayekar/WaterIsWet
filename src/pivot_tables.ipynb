# %%
import os
import pandas as pd

# %%
# All of our CSVs

# GDP / GDP per capita
gdp_df = pd.read_csv(os.path.join('..', 'data', 'eco-conserv-env-health.csv'))
# Land use
land_use_df = pd.read_csv(os.path.join('..', 'data', 'land-use-population.csv'))
# Water resources per area
resources_df = pd.read_csv(os.path.join('..', 'data', 'water-resources.csv'))
# Irrigation statistics
irrigation_df = pd.read_csv(os.path.join('..', 'data', 'water-use-irrigation.csv'))

# %% [markdown]
# ### Check the formatting
# Making sure everything is in the right column

# %%
gdp_df.head()
# Out:
#           Area  Area Id                 Variable Name  Variable Id    Year  \
# 0  Afghanistan      2.0  Gross Domestic Product (GDP)       4112.0  1962.0
# 1  Afghanistan      2.0                GDP per capita       4458.0  1962.0
# 2      Algeria      4.0  Gross Domestic Product (GDP)       4112.0  1962.0
# 3      Algeria      4.0                GDP per capita       4458.0  1962.0
# 4    Argentina      9.0  Gross Domestic Product (GDP)       4112.0  1962.0
#
#           Value Symbol  Md
# 0  5.470000e+08      E NaN
# 1  5.850000e+01      E NaN
# 2  2.000000e+09      E NaN
# 3  1.712000e+02      E NaN
# 4  2.450000e+10      E NaN

# %%
land_use_df.head()
# Out:
#           Area  Area Id                                    Variable Name  \
# 0  Afghanistan      2.0                        Total area of the country
# 1  Afghanistan      2.0                                 Arable land area
# 2  Afghanistan      2.0                             Permanent crops area
# 3  Afghanistan      2.0  Cultivated area (arable land + permanent crops)
# 4  Afghanistan      2.0               % of total country area cultivated
#
#    Variable Id    Year     Value Symbol  Md
# 0       4100.0  1962.0  65286.00      E NaN
# 1       4101.0  1962.0   7700.00      E NaN
# 2       4102.0  1962.0     60.00      E NaN
# 3       4103.0  1962.0   7760.00      E NaN
# 4       4470.0  1962.0     11.89      E NaN

# %%
resources_df.head()
# Out:
#           Area  Area Id                                     Variable Name  \
# 0  Afghanistan      2.0   Long-term average annual precipitation in depth
# 1  Afghanistan      2.0  Long-term average annual precipitation in volume
# 2  Afghanistan      2.0                 Surface water produced internally
# 3  Afghanistan      2.0                   Groundwater produced internally
# 4  Afghanistan      2.0     Overlap between surface water and groundwater
#
#    Variable Id    Year   Value Symbol  Md
# 0       4151.0  1962.0  327.00    NaN NaN
# 1       4150.0  1962.0  213.50      K NaN
# 2       4155.0  1962.0   37.50      K NaN
# 3       4154.0  1962.0   10.65    NaN NaN
# 4       4156.0  1962.0    1.00      K NaN

# %%
irrigation_df.head()
# Out:
#           Area  Area Id                    Variable Name  Variable Id    Year  \
# 0  Afghanistan      2.0  Environmental Flow Requirements       4549.0  1962.0
# 1      Albania      3.0  Environmental Flow Requirements       4549.0  1962.0
# 2      Algeria      4.0  Environmental Flow Requirements       4549.0  1962.0
# 3      Algeria      4.0             Irrigation potential       4307.0  1962.0
# 4       Angola      7.0  Environmental Flow Requirements       4549.0  1962.0
#
#       Value Symbol  Md
# 0    18.890      E NaN
# 1     9.932      E NaN
# 2     2.794      E NaN
# 3  1300.000    NaN NaN
# 4    44.490      E NaN

# %% [markdown]
# ### Make Pivot Tables of all the Data

# %%
gdp_df.columns
# Out:
# Index(['Area', 'Area Id', 'Variable Name', 'Variable Id', 'Year', 'Value',
#        'Symbol', 'Md'],
#       dtype='object')

# %%
gdp_table = gdp_df.pivot_table(index=['Area', 'Variable Name', 'Variable Id'], columns=['Year'], values=['Value',
       'Symbol', 'Md'])

# %%
gdp_table.head()
# Out:
#                                                                             Value  \
# Year                                                                       1960.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0         NaN
#             Flood occurrence (WRI)                             4543.0         NaN
#             GDP per capita                                     4458.0         NaN
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0         NaN
#             Gross Domestic Product (GDP)                       4112.0         NaN
#
#                                                                                          \
# Year                                                                             1962.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0               NaN
#             Flood occurrence (WRI)                             4543.0               NaN
#             GDP per capita                                     4458.0              58.5
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0               NaN
#             Gross Domestic Product (GDP)                       4112.0       547000000.0
#
#                                                                                    \
# Year                                                                       1965.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0         NaN
#             Flood occurrence (WRI)                             4543.0         NaN
#             GDP per capita                                     4458.0         NaN
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0         NaN
#             Gross Domestic Product (GDP)                       4112.0         NaN
#
#                                                                                    \
# Year                                                                       1966.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0         NaN
#             Flood occurrence (WRI)                             4543.0         NaN
#             GDP per capita                                     4458.0         NaN
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0         NaN
#             Gross Domestic Product (GDP)                       4112.0         NaN
#
#                                                                                           \
# Year                                                                              1967.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0                NaN
#             Flood occurrence (WRI)                             4543.0                NaN
#             GDP per capita                                     4458.0       1.614000e+02
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0                NaN
#             Gross Domestic Product (GDP)                       4112.0       1.670000e+09
#
#                                                                                    \
# Year                                                                       1970.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0         NaN
#             Flood occurrence (WRI)                             4543.0         NaN
#             GDP per capita                                     4458.0         NaN
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0         NaN
#             Gross Domestic Product (GDP)                       4112.0         NaN
#
#                                                                                           \
# Year                                                                              1972.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0                NaN
#             Flood occurrence (WRI)                             4543.0                NaN
#             GDP per capita                                     4458.0       1.362000e+02
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0                NaN
#             Gross Domestic Product (GDP)                       4112.0       1.600000e+09
#
#                                                                                    \
# Year                                                                       1974.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0         NaN
#             Flood occurrence (WRI)                             4543.0         NaN
#             GDP per capita                                     4458.0         NaN
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0         NaN
#             Gross Domestic Product (GDP)                       4112.0         NaN
#
#                                                                                    \
# Year                                                                       1975.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0         NaN
#             Flood occurrence (WRI)                             4543.0         NaN
#             GDP per capita                                     4458.0         NaN
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0         NaN
#             Gross Domestic Product (GDP)                       4112.0         NaN
#
#                                                                                           \
# Year                                                                              1977.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0                NaN
#             Flood occurrence (WRI)                             4543.0                NaN
#             GDP per capita                                     4458.0       2.262000e+02
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0                NaN
#             Gross Domestic Product (GDP)                       4112.0       2.950000e+09
#
#                                                                             ...    \
# Year                                                                        ...
# Area        Variable Name                                      Variable Id  ...
# Afghanistan Agriculture, value added (% GDP)                   4113.0       ...
#             Flood occurrence (WRI)                             4543.0       ...
#             GDP per capita                                     4458.0       ...
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0       ...
#             Gross Domestic Product (GDP)                       4112.0       ...
#
#                                                                                           \
# Year                                                                              2007.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0       3.062000e+01
#             Flood occurrence (WRI)                             4543.0                NaN
#             GDP per capita                                     4458.0       3.804000e+02
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0                NaN
#             Gross Domestic Product (GDP)                       4112.0       9.840000e+09
#
#                                                                                    \
# Year                                                                       2008.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0         NaN
#             Flood occurrence (WRI)                             4543.0         NaN
#             GDP per capita                                     4458.0         NaN
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0         NaN
#             Gross Domestic Product (GDP)                       4112.0         NaN
#
#                                                                                    \
# Year                                                                       2009.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0         NaN
#             Flood occurrence (WRI)                             4543.0         NaN
#             GDP per capita                                     4458.0         NaN
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0         NaN
#             Gross Domestic Product (GDP)                       4112.0         NaN
#
#                                                                                    \
# Year                                                                       2010.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0         NaN
#             Flood occurrence (WRI)                             4543.0         NaN
#             GDP per capita                                     4458.0         NaN
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0        0.72
#             Gross Domestic Product (GDP)                       4112.0         NaN
#
#                                                                                    \
# Year                                                                       2011.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0         NaN
#             Flood occurrence (WRI)                             4543.0         NaN
#             GDP per capita                                     4458.0         NaN
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0         NaN
#             Gross Domestic Product (GDP)                       4112.0         NaN
#
#                                                                                           \
# Year                                                                              2012.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0       2.460000e+01
#             Flood occurrence (WRI)                             4543.0                NaN
#             GDP per capita                                     4458.0       6.908000e+02
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0                NaN
#             Gross Domestic Product (GDP)                       4112.0       2.050000e+10
#
#                                                                                    \
# Year                                                                       2013.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0         NaN
#             Flood occurrence (WRI)                             4543.0         3.7
#             GDP per capita                                     4458.0         NaN
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0         NaN
#             Gross Domestic Product (GDP)                       4112.0         NaN
#
#                                                                                     \
# Year                                                                        2014.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0          NaN
#             Flood occurrence (WRI)                             4543.0          NaN
#             GDP per capita                                     4458.0          NaN
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0       0.6934
#             Gross Domestic Product (GDP)                       4112.0          NaN
#
#                                                                                           \
# Year                                                                              2015.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0       2.260000e+01
#             Flood occurrence (WRI)                             4543.0                NaN
#             GDP per capita                                     4458.0       5.903000e+02
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0                NaN
#             Gross Domestic Product (GDP)                       4112.0       1.920000e+10
#
#
# Year                                                                       2016.0
# Area        Variable Name                                      Variable Id
# Afghanistan Agriculture, value added (% GDP)                   4113.0         NaN
#             Flood occurrence (WRI)                             4543.0         NaN
#             GDP per capita                                     4458.0         NaN
#             Gender Inequality Index (GII) [equality = 0; in... 4537.0         NaN
#             Gross Domestic Product (GDP)                       4112.0         NaN
#
# [5 rows x 47 columns]

# %%
land_use_table = land_use_df.pivot_table(index=['Area', 'Variable Name', 'Variable Id'], columns=['Year'], values=['Value',
       'Symbol', 'Md'])

# %%
land_use_table.head()
# Out:
#                                                                            Value  \
# Year                                                                      1962.0
# Area        Variable Name                                   Variable Id
# Afghanistan % of total country area cultivated              4470.0         11.89
#             Arable land area                                4101.0       7700.00
#             Cultivated area (arable land + permanent crops) 4103.0       7760.00
#             Permanent crops area                            4102.0         60.00
#             Population density                              4107.0         14.31
#
#                                                                                   \
# Year                                                                      1967.0
# Area        Variable Name                                   Variable Id
# Afghanistan % of total country area cultivated              4470.0         12.22
#             Arable land area                                4101.0       7844.00
#             Cultivated area (arable land + permanent crops) 4103.0       7979.00
#             Permanent crops area                            4102.0        135.00
#             Population density                              4107.0         15.88
#
#                                                                                   \
# Year                                                                      1972.0
# Area        Variable Name                                   Variable Id
# Afghanistan % of total country area cultivated              4470.0         12.32
#             Arable land area                                4101.0       7910.00
#             Cultivated area (arable land + permanent crops) 4103.0       8046.00
#             Permanent crops area                            4102.0        136.00
#             Population density                              4107.0         17.95
#
#                                                                                   \
# Year                                                                      1977.0
# Area        Variable Name                                   Variable Id
# Afghanistan % of total country area cultivated              4470.0         12.33
#             Arable land area                                4101.0       7910.00
#             Cultivated area (arable land + permanent crops) 4103.0       8050.00
#             Permanent crops area                            4102.0        140.00
#             Population density                              4107.0         20.00
#
#                                                                                   \
# Year                                                                      1982.0
# Area        Variable Name                                   Variable Id
# Afghanistan % of total country area cultivated              4470.0         12.34
#             Arable land area                                4101.0       7910.00
#             Cultivated area (arable land + permanent crops) 4103.0       8054.00
#             Permanent crops area                            4102.0        144.00
#             Population density                              4107.0         19.40
#
#                                                                                   \
# Year                                                                      1987.0
# Area        Variable Name                                   Variable Id
# Afghanistan % of total country area cultivated              4470.0         12.32
#             Arable land area                                4101.0       7910.00
#             Cultivated area (arable land + permanent crops) 4103.0       8045.00
#             Permanent crops area                            4102.0        135.00
#             Population density                              4107.0         17.37
#
#                                                                                   \
# Year                                                                      1992.0
# Area        Variable Name                                   Variable Id
# Afghanistan % of total country area cultivated              4470.0         12.30
#             Arable land area                                4101.0       7910.00
#             Cultivated area (arable land + permanent crops) 4103.0       8030.00
#             Permanent crops area                            4102.0        120.00
#             Population density                              4107.0         21.06
#
#                                                                                   \
# Year                                                                      1997.0
# Area        Variable Name                                   Variable Id
# Afghanistan % of total country area cultivated              4470.0         11.93
#             Arable land area                                4101.0       7685.00
#             Cultivated area (arable land + permanent crops) 4103.0       7790.00
#             Permanent crops area                            4102.0        105.00
#             Population density                              4107.0         27.62
#
#                                                                                   \
# Year                                                                      2002.0
# Area        Variable Name                                   Variable Id
# Afghanistan % of total country area cultivated              4470.0         11.88
#             Arable land area                                4101.0       7678.00
#             Cultivated area (arable land + permanent crops) 4103.0       7753.00
#             Permanent crops area                            4102.0         75.00
#             Population density                              4107.0         32.91
#
#                                                                                   \
# Year                                                                      2007.0
# Area        Variable Name                                   Variable Id
# Afghanistan % of total country area cultivated              4470.0         12.12
#             Arable land area                                4101.0       7794.00
#             Cultivated area (arable land + permanent crops) 4103.0       7910.00
#             Permanent crops area                            4102.0        116.00
#             Population density                              4107.0         39.64
#
#                                                                                   \
# Year                                                                      2012.0
# Area        Variable Name                                   Variable Id
# Afghanistan % of total country area cultivated              4470.0         12.12
#             Arable land area                                4101.0       7790.00
#             Cultivated area (arable land + permanent crops) 4103.0       7910.00
#             Permanent crops area                            4102.0        120.00
#             Population density                              4107.0         45.53
#
#                                                                                 \
# Year                                                                    2013.0
# Area        Variable Name                                   Variable Id
# Afghanistan % of total country area cultivated              4470.0         NaN
#             Arable land area                                4101.0         NaN
#             Cultivated area (arable land + permanent crops) 4103.0         NaN
#             Permanent crops area                            4102.0         NaN
#             Population density                              4107.0         NaN
#
#                                                                                   \
# Year                                                                      2014.0
# Area        Variable Name                                   Variable Id
# Afghanistan % of total country area cultivated              4470.0         12.12
#             Arable land area                                4101.0       7771.00
#             Cultivated area (arable land + permanent crops) 4103.0       7910.00
#             Permanent crops area                            4102.0        139.00
#             Population density                              4107.0           NaN
#
#
# Year                                                                    2015.0
# Area        Variable Name                                   Variable Id
# Afghanistan % of total country area cultivated              4470.0         NaN
#             Arable land area                                4101.0         NaN
#             Cultivated area (arable land + permanent crops) 4103.0         NaN
#             Permanent crops area                            4102.0         NaN
#             Population density                              4107.0       49.82

# %%
resources_table = resources_df.pivot_table(index=['Area', 'Variable Name', 'Variable Id'], columns=['Year'], values=['Value',
       'Symbol', 'Md'])

# %%
resources_table.head()
# Out:
#                                                                    Value  \
# Year                                                              1960.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0       128.4
#             Dependency ratio                          4192.0         NaN
#             Groundwater produced internally           4154.0         NaN
#             Groundwater: accounted inflow             4452.0         NaN
#             Groundwater: entering the country (total) 4177.0         NaN
#
#                                                                           \
# Year                                                              1962.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0         NaN
#             Dependency ratio                          4192.0       28.72
#             Groundwater produced internally           4154.0       10.65
#             Groundwater: accounted inflow             4452.0        0.00
#             Groundwater: entering the country (total) 4177.0        0.00
#
#                                                                           \
# Year                                                              1963.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0         NaN
#             Dependency ratio                          4192.0         NaN
#             Groundwater produced internally           4154.0         NaN
#             Groundwater: accounted inflow             4452.0         NaN
#             Groundwater: entering the country (total) 4177.0         NaN
#
#                                                                           \
# Year                                                              1964.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0         NaN
#             Dependency ratio                          4192.0         NaN
#             Groundwater produced internally           4154.0         NaN
#             Groundwater: accounted inflow             4452.0         NaN
#             Groundwater: entering the country (total) 4177.0         NaN
#
#                                                                           \
# Year                                                              1965.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0       115.7
#             Dependency ratio                          4192.0         NaN
#             Groundwater produced internally           4154.0         NaN
#             Groundwater: accounted inflow             4452.0         NaN
#             Groundwater: entering the country (total) 4177.0         NaN
#
#                                                                           \
# Year                                                              1966.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0         NaN
#             Dependency ratio                          4192.0         NaN
#             Groundwater produced internally           4154.0         NaN
#             Groundwater: accounted inflow             4452.0         NaN
#             Groundwater: entering the country (total) 4177.0         NaN
#
#                                                                           \
# Year                                                              1967.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0         NaN
#             Dependency ratio                          4192.0       28.72
#             Groundwater produced internally           4154.0       10.65
#             Groundwater: accounted inflow             4452.0        0.00
#             Groundwater: entering the country (total) 4177.0        0.00
#
#                                                                           \
# Year                                                              1968.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0         NaN
#             Dependency ratio                          4192.0         NaN
#             Groundwater produced internally           4154.0         NaN
#             Groundwater: accounted inflow             4452.0         NaN
#             Groundwater: entering the country (total) 4177.0         NaN
#
#                                                                           \
# Year                                                              1969.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0         NaN
#             Dependency ratio                          4192.0         NaN
#             Groundwater produced internally           4154.0         NaN
#             Groundwater: accounted inflow             4452.0         NaN
#             Groundwater: entering the country (total) 4177.0         NaN
#
#                                                                           \
# Year                                                              1970.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0       171.5
#             Dependency ratio                          4192.0         NaN
#             Groundwater produced internally           4154.0         NaN
#             Groundwater: accounted inflow             4452.0         NaN
#             Groundwater: entering the country (total) 4177.0         NaN
#
#                                                                    ...    \
# Year                                                               ...
# Area        Variable Name                             Variable Id  ...
# Afghanistan Dam capacity per capita                   4471.0       ...
#             Dependency ratio                          4192.0       ...
#             Groundwater produced internally           4154.0       ...
#             Groundwater: accounted inflow             4452.0       ...
#             Groundwater: entering the country (total) 4177.0       ...
#
#                                                                           \
# Year                                                              2006.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0         NaN
#             Dependency ratio                          4192.0         NaN
#             Groundwater produced internally           4154.0         NaN
#             Groundwater: accounted inflow             4452.0         NaN
#             Groundwater: entering the country (total) 4177.0         NaN
#
#                                                                           \
# Year                                                              2007.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0         NaN
#             Dependency ratio                          4192.0       28.72
#             Groundwater produced internally           4154.0       10.65
#             Groundwater: accounted inflow             4452.0        0.00
#             Groundwater: entering the country (total) 4177.0        0.00
#
#                                                                           \
# Year                                                              2008.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0         NaN
#             Dependency ratio                          4192.0         NaN
#             Groundwater produced internally           4154.0         NaN
#             Groundwater: accounted inflow             4452.0         NaN
#             Groundwater: entering the country (total) 4177.0         NaN
#
#                                                                           \
# Year                                                              2009.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0         NaN
#             Dependency ratio                          4192.0         NaN
#             Groundwater produced internally           4154.0         NaN
#             Groundwater: accounted inflow             4452.0         NaN
#             Groundwater: entering the country (total) 4177.0         NaN
#
#                                                                           \
# Year                                                              2010.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0       67.58
#             Dependency ratio                          4192.0         NaN
#             Groundwater produced internally           4154.0         NaN
#             Groundwater: accounted inflow             4452.0         NaN
#             Groundwater: entering the country (total) 4177.0         NaN
#
#                                                                           \
# Year                                                              2011.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0         NaN
#             Dependency ratio                          4192.0         NaN
#             Groundwater produced internally           4154.0         NaN
#             Groundwater: accounted inflow             4452.0         NaN
#             Groundwater: entering the country (total) 4177.0         NaN
#
#                                                                           \
# Year                                                              2012.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0         NaN
#             Dependency ratio                          4192.0       28.72
#             Groundwater produced internally           4154.0       10.65
#             Groundwater: accounted inflow             4452.0        0.00
#             Groundwater: entering the country (total) 4177.0        0.00
#
#                                                                           \
# Year                                                              2013.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0         NaN
#             Dependency ratio                          4192.0         NaN
#             Groundwater produced internally           4154.0         NaN
#             Groundwater: accounted inflow             4452.0         NaN
#             Groundwater: entering the country (total) 4177.0         NaN
#
#                                                                           \
# Year                                                              2014.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0         NaN
#             Dependency ratio                          4192.0       28.72
#             Groundwater produced internally           4154.0       10.65
#             Groundwater: accounted inflow             4452.0        0.00
#             Groundwater: entering the country (total) 4177.0        0.00
#
#
# Year                                                              2015.0
# Area        Variable Name                             Variable Id
# Afghanistan Dam capacity per capita                   4471.0       61.76
#             Dependency ratio                          4192.0         NaN
#             Groundwater produced internally           4154.0         NaN
#             Groundwater: accounted inflow             4452.0         NaN
#             Groundwater: entering the country (total) 4177.0         NaN
#
# [5 rows x 55 columns]

# %%
irrigation_table = irrigation_df.pivot_table(index=['Area', 'Variable Name', 'Variable Id'], columns=['Year'], values=['Value',
       'Symbol', 'Md'])

# %%
irrigation_table.head()
# Out:
#                                                                             Value  \
# Year                                                                       1958.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
#                                                                                    \
# Year                                                                       1961.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
#                                                                                    \
# Year                                                                       1962.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
#                                                                                    \
# Year                                                                       1963.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
#                                                                                    \
# Year                                                                       1964.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
#                                                                                    \
# Year                                                                       1965.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
#                                                                                    \
# Year                                                                       1966.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
#                                                                                    \
# Year                                                                       1967.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0       100.0
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0        15.4
#             % of area equipped for irrigation by mixed surf... 4325.0         0.0
#             % of area equipped for irrigation by surface water 4324.0        84.6
#
#                                                                                    \
# Year                                                                       1969.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
#                                                                                    \
# Year                                                                       1970.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
#                                                                             ...    \
# Year                                                                        ...
# Area        Variable Name                                      Variable Id  ...
# Afghanistan % of agricultural water managed area equipped f... 4319.0       ...
#             % of area equipped for full control irrigation ... 4463.0       ...
#             % of area equipped for irrigation by groundwater   4323.0       ...
#             % of area equipped for irrigation by mixed surf... 4325.0       ...
#             % of area equipped for irrigation by surface water 4324.0       ...
#
#                                                                                    \
# Year                                                                       2008.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
#                                                                                    \
# Year                                                                       2009.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
#                                                                                    \
# Year                                                                       2010.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
#                                                                                    \
# Year                                                                       2011.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
#                                                                                    \
# Year                                                                       2012.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
#                                                                                    \
# Year                                                                       2013.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
#                                                                                    \
# Year                                                                       2014.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
#                                                                                    \
# Year                                                                       2015.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
#                                                                                    \
# Year                                                                       2016.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
#
# Year                                                                       2017.0
# Area        Variable Name                                      Variable Id
# Afghanistan % of agricultural water managed area equipped f... 4319.0         NaN
#             % of area equipped for full control irrigation ... 4463.0         NaN
#             % of area equipped for irrigation by groundwater   4323.0         NaN
#             % of area equipped for irrigation by mixed surf... 4325.0         NaN
#             % of area equipped for irrigation by surface water 4324.0         NaN
#
# [5 rows x 55 columns]

# %%
import pandas as pd

# %%
df = pd.read_csv("data/aquastat_population.csv")

# %%
df
# Out:
#                                                      Area  \
# Afghanistan                                           2.0
# Afghanistan                                           2.0
# Afghanistan                                           2.0
# Afghanistan                                           2.0
# Afghanistan                                           2.0
# Afghanistan                                           2.0
# Afghanistan                                           2.0
# Afghanistan                                           2.0
# Afghanistan                                           2.0
# Afghanistan                                           2.0
# Afghanistan                                           2.0
# Afghanistan                                           2.0
# Afghanistan                                           2.0
# Afghanistan                                           2.0
# Afghanistan                                           2.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20788 entries, Afghanistan to FAO. 2016. AQUASTAT Main Database - Food and Agriculture Organization of the United Nations (FAO). Website accessed on[16/05/2018 4:4]
# Data columns (total 8 columns):
# Area             20775 non-null float64
# Area Id          20775 non-null object
# Variable Name    20775 non-null float64
# Variable Id      20775 non-null float64
# Year             20775 non-null float64
# Value            20770 non-null object
# Symbol           4 non-null object
# Md               0 non-null float64
# dtypes: float64(5), object(3)
# memory usage: 1.4+ MB

# %%
df["Area"]
# Out:
# Afghanistan                                                                                                                                 2.0
# Afghanistan                                                                                                                                 2.0
# Afghanistan                                                                                                                                 2.0
# Afghanistan                                                                                                                                 2.0
# Afghanistan                                                                                                                                 2.0
# Afghanistan                                                                                                                                 2.0
# ...
